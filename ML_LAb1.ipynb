# %% [markdown]
# <a href="https://colab.research.google.com/github/manoj21101/manoj21101.github.io/blob/main/ML_LAb1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = [['apple',10,240],['orange',15,80],['grapes',14,80],['pineapple',10,70]]
df1 = pd.DataFrame(data, columns= ['Fruit_name','Quanttity','Unit_price'])
df1
# Out:
#   Fruit_name  Quanttity  Unit_price
# 0      apple         10         240
# 1     orange         15          80
# 2     grapes         14          80
# 3  pineapple         10          70

# %%
df1.describe()
# Out:
#        Quanttity  Unit_price
# count   4.000000    4.000000
# mean   12.250000  117.500000
# std     2.629956   81.802608
# min    10.000000   70.000000
# 25%    10.000000   77.500000
# 50%    12.000000   80.000000
# 75%    14.250000  120.000000
# max    15.000000  240.000000

# %%
df1.columns
# Out:
# Index(['Fruit_name', 'Quanttity', 'Unit_price'], dtype='object')

# %%
df1.info
# Out:
# <bound method DataFrame.info of   Fruit_name  Quanttity  Unit_price
# 0      apple         10         240
# 1     orange         15          80
# 2     grapes         14          80
# 3  pineapple         10          70>

# %%
df1.head(2)
# Out:
#   Fruit_name  Quanttity  Unit_price
# 0      apple         10         240
# 1     orange         15          80

# %%
df1.tail(2)
# Out:
#   Fruit_name  Quanttity  Unit_price
# 2     grapes         14          80
# 3  pineapple         10          70

# %%
df1.sample(2)
# Out:
#   Fruit_name  Quanttity  Unit_price
# 0      apple         10         240
# 3  pineapple         10          70

# %%
df1.dtypes
# Out:
# Fruit_name    object
# Quanttity      int64
# Unit_price     int64
# dtype: object

# %%
df1['Quanttity'].dtype
# Out:
# dtype('int64')
